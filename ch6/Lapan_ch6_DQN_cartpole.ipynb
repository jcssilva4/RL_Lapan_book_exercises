# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !git clone https://github.com/openai/gym.git
# %cd gym
# !pip install -e .
# %cd ..
# Out:
# fatal: destination path 'gym' already exists and is not an empty directory.
# /content/gym
# Obtaining file:///content/gym
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym==0.18.0) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym==0.18.0) (1.19.5)
# Requirement already satisfied: pyglet>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.18.0) (1.5.0)
# Requirement already satisfied: Pillow<=8.2.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.18.0) (7.1.2)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.18.0) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet>=1.4.0->gym==0.18.0) (0.16.0)
# Installing collected packages: gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.18.0
#     Can't uninstall 'gym'. No files were found to uninstall.
#   Running setup.py develop for gym
# Successfully installed gym-0.18.0
# /content

# %%
# reinitialize the exec env
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment 
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %% [markdown]
# # **Agente** (Rede neural)
#
# *   Output da rede -> $Q(s,a)$ para todo estado $s$ e para toda ação $a$

# %%
from torch import nn

class DQN(nn.Module):
  def __init__(self, input_shape, n_actions):
    super(DQN, self).__init__()
    self.crit_dense1 = nn.Linear(in_features =  input_shape[0], out_features = 64)
    self.relu1 = nn.ReLU()
    self.crit_dense2 = nn.Linear(in_features =  64, out_features = 64)
    self.relu2 = nn.ReLU()
    self.crit_dense3 = nn.Linear(in_features =  64, out_features = 64)
    self.relu3 = nn.ReLU()
    self.crit_dense4 = nn.Linear(in_features =  64, out_features = 64)
    self.relu4 = nn.ReLU()
    self.crit_dense5 = nn.Linear(in_features =  64, out_features = n_actions)

  def forward(self, x):
    #print("forward1")
    #print(x)
    out = self.relu1(self.crit_dense1(x))
    #print("forward2")
    out = self.relu2(self.crit_dense2(out))
    #print("forward3")
    out = self.relu3(self.crit_dense3(out))
    #print("forward4")
    out = self.relu4(self.crit_dense4(out))
    #print("forward5")
    out =self.crit_dense5(out)
    return out

# %% [markdown]
# # **Parâmetros de treinamento**

# %%
import argparse
import time
import numpy as np
import collections
import torch
import torch.nn as nn
import torch.optim as optim

DEFAULT_ENV_NAME = "CartPole-v0"
MEAN_REWARD_BOUND = 150.0
GAMMA = 0.9
BATCH_SIZE = 64
REPLAY_SIZE = 10000
REPLAY_START_SIZE = 10000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 1000
EPSILON_DECAY_LAST_FRAME = 150000
EPSILON_START = 0.3
EPSILON_FINAL = 0.01

# %% [markdown]
# # Definição do **replay buffer**

# %%
Experience = collections.namedtuple(
'Experience', field_names=['state', 'action', 'reward',
'done', 'new_state'])

class ExperienceBuffer:
  def __init__(self, capacity):
    self.buffer = collections.deque(maxlen=capacity)

  def __len__(self):
    return len(self.buffer)

  def append(self, experience):
    self.buffer.append(experience)

  def sample(self, batch_size):
    indices = np.random.choice(len(self.buffer), batch_size,
    replace=False)
    states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])
    return np.array(states), np.array(actions), \
            np.array(rewards, dtype=np.float32), \
            np.array(dones, dtype=np.uint8), \
            np.array(next_states)

# %% [markdown]
# # Definição do **Agente**

# %%
class Agent:
  def __init__(self, env, exp_buffer):
    self.env = env
    self.exp_buffer = exp_buffer
    self._reset()

  def _reset(self):
    self.state = env.reset()
    self.total_reward = 0.0

  @torch.no_grad()
  def play_step(self, net, epsilon=0.0, device="cpu"):
    done_reward = None
    if np.random.random() < epsilon:
      action = env.action_space.sample()
    else:
      state_a = np.array([self.state], copy=False)
      state_v = torch.tensor(state_a.astype(np.float32)).to(device)
      q_vals_v = net(state_v)
      _, act_v = torch.max(q_vals_v, dim=1)
      action = int(act_v.item())
    
    new_state, reward, is_done, _ = self.env.step(action)
    self.total_reward += reward

    exp = Experience(self.state, action, reward,
    is_done, new_state)
    self.exp_buffer.append(exp)
    self.state = new_state

    if is_done:
      done_reward = self.total_reward
      self._reset()

    return done_reward

# %% [markdown]
# # Definição da **função perda**

# %%
def calc_loss(batch, net, tgt_net, device="cpu"):
    states, actions, rewards, dones, next_states = batch

    states_v = torch.tensor(states.astype(np.float32)).to(device)
    next_states_v = torch.tensor(next_states.astype(np.float32)).to(device)
    actions_v = torch.tensor(actions).to(device)
    rewards_v = torch.tensor(rewards).to(device)
    done_mask = torch.ByteTensor(dones).to(device)

    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)
    next_state_values = tgt_net(next_states_v).max(1)[0]
    next_state_values[done_mask] = 0.0
    next_state_values = next_state_values.detach()

    expected_state_action_values = next_state_values * GAMMA + rewards_v
    return nn.MSELoss()(state_action_values, expected_state_action_values)

# %% [markdown]
# # Loop principal

# %%
import gym 

use_cuda = False
device = torch.device("cuda" if use_cuda else "cpu")

env = gym.make(DEFAULT_ENV_NAME)

net = DQN(env.observation_space.shape, env.action_space.n).to(device)
tgt_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
print(net)

buffer = ExperienceBuffer(REPLAY_SIZE)
agent = Agent(env, buffer)
epsilon = EPSILON_START

optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
total_rewards = []
frame_idx = 0
ts_frame = 0
ts = time.time()
best_mean_reward = None

while True:
    frame_idx += 1
    epsilon = max(EPSILON_FINAL, EPSILON_START - frame_idx / EPSILON_DECAY_LAST_FRAME)

    reward = agent.play_step(net, epsilon, device=device)
    if reward is not None:
        total_rewards.append(reward)
        speed = (frame_idx - ts_frame) / (time.time() - ts)
        ts_frame = frame_idx
        ts = time.time()
        mean_reward = np.mean(total_rewards[-100:])
        print("%d: done %d games, mean reward %.3f, eps %.2f, speed %.2f f/s" % (
            frame_idx, len(total_rewards), mean_reward, epsilon,
            speed
        ))
        if best_mean_reward is None or best_mean_reward < mean_reward:
            torch.save(net.state_dict(), DEFAULT_ENV_NAME + "-best.dat")
            if best_mean_reward is not None:
                print("Best mean reward updated %.3f -> %.3f, model saved" % (best_mean_reward, mean_reward))
            best_mean_reward = mean_reward
        if mean_reward > MEAN_REWARD_BOUND:
            print("Solved in %d frames!" % frame_idx)
            break

    if len(buffer) < REPLAY_START_SIZE:
        continue

    if frame_idx % SYNC_TARGET_FRAMES == 0:
        tgt_net.load_state_dict(net.state_dict())

    optimizer.zero_grad()
    batch = buffer.sample(BATCH_SIZE)
    loss_t = calc_loss(batch, net, tgt_net, device=device)
    loss_t.backward()
    optimizer.step()
# Out:
# DQN(
#   (crit_dense1): Linear(in_features=4, out_features=64, bias=True)
#   (relu1): ReLU()
#   (crit_dense2): Linear(in_features=64, out_features=64, bias=True)
#   (relu2): ReLU()
#   (crit_dense3): Linear(in_features=64, out_features=64, bias=True)
#   (relu3): ReLU()
#   (crit_dense4): Linear(in_features=64, out_features=64, bias=True)
#   (relu4): ReLU()
# 14483: done 1286 games, mean reward 13.940, eps 0.20, speed 351.48 f/s
# Best mean reward updated 13.220 -> 13.940, model saved
# 14530: done 1287 games, mean reward 14.280, eps 0.20, speed 381.21 f/s
# Best mean reward updated 13.940 -> 14.280, model saved
# 14562: done 1288 games, mean reward 14.500, eps 0.20, speed 328.97 f/s
# Best mean reward updated 14.280 -> 14.500, model saved
# 14594: done 1289 games, mean reward 14.690, eps 0.20, speed 346.86 f/s
# Best mean reward updated 14.500 -> 14.690, model saved
# 14613: done 1290 games, mean reward 14.800, eps 0.20, speed 342.16 f/s
# Best mean reward updated 14.690 -> 14.800, model saved
# 14628: done 1291 games, mean reward 14.860, eps 0.20, speed 370.33 f/s
# Best mean reward updated 14.800 -> 14.860, model saved
# 14676: done 1292 games, mean reward 15.240, eps 0.20, speed 337.20 f/s
# Best mean reward updated 14.860 -> 15.240, model saved
# 14691: done 1293 games, mean reward 15.270, eps 0.20, speed 367.18 f/s
# Best mean reward updated 15.240 -> 15.270, model saved
# 14718: done 1294 games, mean reward 15.430, eps 0.20, speed 343.04 f/s
# Best mean reward updated 15.270 -> 15.430, model saved
# 14776: done 1295 games, mean reward 15.900, eps 0.20, speed 355.15 f/s
# Best mean reward updated 15.430 -> 15.900, model saved
# 14825: done 1296 games, mean reward 16.250, eps 0.20, speed 351.32 f/s
# Best mean reward updated 15.900 -> 16.250, model saved
# 14898: done 1297 games, mean reward 16.870, eps 0.20, speed 347.79 f/s
# Best mean reward updated 16.250 -> 16.870, model saved
# 14978: done 1298 games, mean reward 17.560, eps 0.20, speed 357.42 f/s
# Best mean reward updated 16.870 -> 17.560, model saved
# 15020: done 1299 games, mean reward 17.890, eps 0.20, speed 374.41 f/s
# Best mean reward updated 17.560 -> 17.890, model saved
# 15090: done 1300 games, mean reward 18.420, eps 0.20, speed 354.86 f/s
# Best mean reward updated 17.890 -> 18.420, model saved
# 15162: done 1301 games, mean reward 19.040, eps 0.20, speed 350.54 f/s
# Best mean reward updated 18.420 -> 19.040, model saved
# 15205: done 1302 games, mean reward 19.360, eps 0.20, speed 371.18 f/s
# Best mean reward updated 19.040 -> 19.360, model saved
# 15276: done 1303 games, mean reward 19.960, eps 0.20, speed 369.88 f/s
# Best mean reward updated 19.360 -> 19.960, model saved
# 15348: done 1304 games, mean reward 20.590, eps 0.20, speed 366.47 f/s
# Best mean reward updated 19.960 -> 20.590, model saved
# 15441: done 1305 games, mean reward 21.400, eps 0.20, speed 348.51 f/s
# Best mean reward updated 20.590 -> 21.400, model saved
# 15641: done 1306 games, mean reward 23.300, eps 0.20, speed 368.01 f/s
# Best mean reward updated 21.400 -> 23.300, model saved
# 15760: done 1307 games, mean reward 24.390, eps 0.19, speed 370.97 f/s
# Best mean reward updated 23.300 -> 24.390, model saved
# 15909: done 1308 games, mean reward 25.800, eps 0.19, speed 360.06 f/s
# Best mean reward updated 24.390 -> 25.800, model saved
# 16109: done 1309 games, mean reward 27.700, eps 0.19, speed 377.09 f/s
# Best mean reward updated 25.800 -> 27.700, model saved
# 16274: done 1310 games, mean reward 29.230, eps 0.19, speed 351.27 f/s
# Best mean reward updated 27.700 -> 29.230, model saved
# 16444: done 1311 games, mean reward 30.840, eps 0.19, speed 371.50 f/s
# Best mean reward updated 29.230 -> 30.840, model saved
# 16644: done 1312 games, mean reward 32.750, eps 0.19, speed 376.86 f/s
# Best mean reward updated 30.840 -> 32.750, model saved
# 16779: done 1313 games, mean reward 34.000, eps 0.19, speed 368.10 f/s
# Best mean reward updated 32.750 -> 34.000, model saved
# 16979: done 1314 games, mean reward 35.910, eps 0.19, speed 360.79 f/s
# Best mean reward updated 34.000 -> 35.910, model saved
# 17179: done 1315 games, mean reward 37.790, eps 0.19, speed 380.74 f/s
# Best mean reward updated 35.910 -> 37.790, model saved
# 17379: done 1316 games, mean reward 39.680, eps 0.18, speed 364.37 f/s
# Best mean reward updated 37.790 -> 39.680, model saved
# 17579: done 1317 games, mean reward 41.590, eps 0.18, speed 374.14 f/s
# Best mean reward updated 39.680 -> 41.590, model saved
# 17779: done 1318 games, mean reward 43.490, eps 0.18, speed 377.78 f/s
# Best mean reward updated 41.590 -> 43.490, model saved
# 17979: done 1319 games, mean reward 45.400, eps 0.18, speed 381.65 f/s
# Best mean reward updated 43.490 -> 45.400, model saved
# 18179: done 1320 games, mean reward 47.230, eps 0.18, speed 351.92 f/s
# Best mean reward updated 45.400 -> 47.230, model saved
# 18379: done 1321 games, mean reward 49.120, eps 0.18, speed 394.15 f/s
# Best mean reward updated 47.230 -> 49.120, model saved
# 18579: done 1322 games, mean reward 51.010, eps 0.18, speed 380.86 f/s
# Best mean reward updated 49.120 -> 51.010, model saved
# 18779: done 1323 games, mean reward 52.800, eps 0.17, speed 369.75 f/s
# Best mean reward updated 51.010 -> 52.800, model saved
# 18979: done 1324 games, mean reward 54.700, eps 0.17, speed 370.06 f/s
# Best mean reward updated 52.800 -> 54.700, model saved
# 19179: done 1325 games, mean reward 56.600, eps 0.17, speed 382.79 f/s
# Best mean reward updated 54.700 -> 56.600, model saved
# 19379: done 1326 games, mean reward 58.460, eps 0.17, speed 374.51 f/s
# Best mean reward updated 56.600 -> 58.460, model saved
# 19579: done 1327 games, mean reward 60.350, eps 0.17, speed 367.73 f/s
# Best mean reward updated 58.460 -> 60.350, model saved
# 19779: done 1328 games, mean reward 62.250, eps 0.17, speed 369.40 f/s
# Best mean reward updated 60.350 -> 62.250, model saved
# 19979: done 1329 games, mean reward 64.140, eps 0.17, speed 385.09 f/s
# Best mean reward updated 62.250 -> 64.140, model saved
# 20179: done 1330 games, mean reward 66.030, eps 0.17, speed 367.48 f/s
# Best mean reward updated 64.140 -> 66.030, model saved
# 20379: done 1331 games, mean reward 67.920, eps 0.16, speed 361.27 f/s
# Best mean reward updated 66.030 -> 67.920, model saved
# 20566: done 1332 games, mean reward 69.700, eps 0.16, speed 371.73 f/s
# Best mean reward updated 67.920 -> 69.700, model saved
# 20766: done 1333 games, mean reward 71.590, eps 0.16, speed 367.86 f/s
# Best mean reward updated 69.700 -> 71.590, model saved
# 20966: done 1334 games, mean reward 73.500, eps 0.16, speed 373.16 f/s
# Best mean reward updated 71.590 -> 73.500, model saved
# 21166: done 1335 games, mean reward 75.350, eps 0.16, speed 380.85 f/s
# Best mean reward updated 73.500 -> 75.350, model saved
# 21366: done 1336 games, mean reward 77.230, eps 0.16, speed 368.95 f/s
# Best mean reward updated 75.350 -> 77.230, model saved
# 21566: done 1337 games, mean reward 79.130, eps 0.16, speed 386.36 f/s
# Best mean reward updated 77.230 -> 79.130, model saved
# 21766: done 1338 games, mean reward 80.980, eps 0.15, speed 368.05 f/s
# Best mean reward updated 79.130 -> 80.980, model saved
# 21966: done 1339 games, mean reward 82.770, eps 0.15, speed 355.70 f/s
# Best mean reward updated 80.980 -> 82.770, model saved
# 22166: done 1340 games, mean reward 84.670, eps 0.15, speed 365.05 f/s
# Best mean reward updated 82.770 -> 84.670, model saved
# 22366: done 1341 games, mean reward 86.550, eps 0.15, speed 352.28 f/s
# Best mean reward updated 84.670 -> 86.550, model saved
# 22566: done 1342 games, mean reward 88.460, eps 0.15, speed 354.07 f/s
# Best mean reward updated 86.550 -> 88.460, model saved
# 22766: done 1343 games, mean reward 90.370, eps 0.15, speed 348.57 f/s
# Best mean reward updated 88.460 -> 90.370, model saved
# 22940: done 1344 games, mean reward 92.000, eps 0.15, speed 359.92 f/s
# Best mean reward updated 90.370 -> 92.000, model saved
# 23140: done 1345 games, mean reward 93.840, eps 0.15, speed 350.81 f/s
# Best mean reward updated 92.000 -> 93.840, model saved
# 23340: done 1346 games, mean reward 95.730, eps 0.14, speed 367.09 f/s
# Best mean reward updated 93.840 -> 95.730, model saved
# 23540: done 1347 games, mean reward 97.620, eps 0.14, speed 370.93 f/s
# Best mean reward updated 95.730 -> 97.620, model saved
# 23740: done 1348 games, mean reward 99.500, eps 0.14, speed 371.55 f/s
# Best mean reward updated 97.620 -> 99.500, model saved
# 23940: done 1349 games, mean reward 101.420, eps 0.14, speed 365.25 f/s
# Best mean reward updated 99.500 -> 101.420, model saved
# 24140: done 1350 games, mean reward 103.270, eps 0.14, speed 378.53 f/s
# Best mean reward updated 101.420 -> 103.270, model saved
# 24340: done 1351 games, mean reward 105.160, eps 0.14, speed 356.02 f/s
# Best mean reward updated 103.270 -> 105.160, model saved
# 24540: done 1352 games, mean reward 107.070, eps 0.14, speed 359.28 f/s
# Best mean reward updated 105.160 -> 107.070, model saved
# 24740: done 1353 games, mean reward 108.960, eps 0.14, speed 366.42 f/s
# Best mean reward updated 107.070 -> 108.960, model saved
# 24940: done 1354 games, mean reward 110.850, eps 0.13, speed 368.31 f/s
# Best mean reward updated 108.960 -> 110.850, model saved
# 25140: done 1355 games, mean reward 112.750, eps 0.13, speed 367.28 f/s
# Best mean reward updated 110.850 -> 112.750, model saved
# 25340: done 1356 games, mean reward 114.660, eps 0.13, speed 353.72 f/s
# Best mean reward updated 112.750 -> 114.660, model saved
# 25540: done 1357 games, mean reward 116.560, eps 0.13, speed 369.38 f/s
# Best mean reward updated 114.660 -> 116.560, model saved
# 25740: done 1358 games, mean reward 118.450, eps 0.13, speed 367.94 f/s
# Best mean reward updated 116.560 -> 118.450, model saved
# 25940: done 1359 games, mean reward 120.340, eps 0.13, speed 372.37 f/s
# Best mean reward updated 118.450 -> 120.340, model saved
# 26140: done 1360 games, mean reward 122.210, eps 0.13, speed 367.62 f/s
# Best mean reward updated 120.340 -> 122.210, model saved
# 26329: done 1361 games, mean reward 124.000, eps 0.12, speed 374.19 f/s
# Best mean reward updated 122.210 -> 124.000, model saved
# 26527: done 1362 games, mean reward 125.870, eps 0.12, speed 350.44 f/s
# Best mean reward updated 124.000 -> 125.870, model saved
# 26727: done 1363 games, mean reward 127.720, eps 0.12, speed 389.05 f/s
# Best mean reward updated 125.870 -> 127.720, model saved
# 26927: done 1364 games, mean reward 129.580, eps 0.12, speed 353.00 f/s
# Best mean reward updated 127.720 -> 129.580, model saved
# 27127: done 1365 games, mean reward 131.480, eps 0.12, speed 385.83 f/s
# Best mean reward updated 129.580 -> 131.480, model saved
# 27327: done 1366 games, mean reward 133.380, eps 0.12, speed 363.81 f/s
# Best mean reward updated 131.480 -> 133.380, model saved
# 27523: done 1367 games, mean reward 135.100, eps 0.12, speed 370.61 f/s
# Best mean reward updated 133.380 -> 135.100, model saved
# 27723: done 1368 games, mean reward 136.970, eps 0.12, speed 364.73 f/s
# Best mean reward updated 135.100 -> 136.970, model saved
# 27923: done 1369 games, mean reward 138.870, eps 0.11, speed 353.62 f/s
# Best mean reward updated 136.970 -> 138.870, model saved
# 28123: done 1370 games, mean reward 140.670, eps 0.11, speed 364.74 f/s
# Best mean reward updated 138.870 -> 140.670, model saved
# 28323: done 1371 games, mean reward 142.560, eps 0.11, speed 343.69 f/s
# Best mean reward updated 140.670 -> 142.560, model saved
# 28523: done 1372 games, mean reward 144.450, eps 0.11, speed 387.00 f/s
# Best mean reward updated 142.560 -> 144.450, model saved
# 28723: done 1373 games, mean reward 146.310, eps 0.11, speed 363.01 f/s
# Best mean reward updated 144.450 -> 146.310, model saved
# 28923: done 1374 games, mean reward 148.200, eps 0.11, speed 376.17 f/s
# Best mean reward updated 146.310 -> 148.200, model saved
# 29119: done 1375 games, mean reward 150.060, eps 0.11, speed 362.03 f/s
# Best mean reward updated 148.200 -> 150.060, model saved
# Solved in 29119 frames!

# %% [markdown]
# Agora Podemos ver o agente treinado em ação

# %%
env = wrap_env(gym.make("CartPole-v0"))
observation = env.reset()
sm = nn.Softmax(dim=1)
for i in range(1):
  done = False
  while not done:
    env.render()
    obs_v = torch.FloatTensor([observation])
    act_probs_v = sm(net(obs_v))
    act_probs = act_probs_v.data.numpy()[0]
    action = np.random.choice(len(act_probs), p=act_probs)
    observation, reward, done, info = env.step(action)     
    #if done:
    #    observation = env.reset() 

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# Agente com politica aleatória

# %%
env = wrap_env(gym.make("CartPole-v0"))
observation = env.reset()
for i in range(1):
  done = False
  while not done:
    env.render()
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)     
    #if done:
    #    observation = env.reset() 

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
